# %% [markdown]
# <a href="https://colab.research.google.com/github/tluciad/python-beginner/blob/main/Overview_of_Colaboratory_Features.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.linspace(0,5,11)
y=x**2

# %%
from matplotlib import axes
fig, axes = plt.subplots(nrows=1, ncols=2)
axes[0].plot(x,y,'b')
axes[1].plot(y,x,'r')

# %%
fig, axes=plt.subplots(2,3)
axes[0, 0].plot(x,np.cos(x), 'g')
axes[0, 1].plot(np.sin(x), 'rD-')
axes[0, 2].plot(np.tan(y), 'yo-')

axes[1,0].plot(y,np.cos(y), 'g:')
axes[1,1].plot(np.sin(y), 'bD')
axes[1,2].plot(np.tan(x), 'ro-')
fig.tight_layout()

# %%
#The other way
fig, ((ax1,ax2,ax3),(ax4,ax5,ax6))=plt.subplots(2,3)
ax1.plot(x,np.cos(x), 'g')
ax2.plot(np.sin(x),'rD-')
ax3.plot(np.tan(y), 'yo-')

ax4.plot(y,np.cos(y), 'g:')
ax5.plot(np.sin(y), 'bD')
ax6.plot(np.tan(x), 'ro-')
fig.tight_layout()

# %%
#color and style pyplot
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']
# 'fig, ((ax1,ax2,ax3),(ax4,ax5,ax6))=plt.subplots(2,3)\nax1.plot(x,np.cos(x), color="#D426C8")\nax2.plot(np.sin(x), color="66FF89")\nax3.plot(np.tan(y), color="55DDC6")\n\nax4.plot(y,np.cos(y), color="blue")\nax5.plot(np.sin(y), color="red")\nax6.plot(np.tan(x), color="green")\nfig.tight_layout()'

# %%
plt.style.use('_classic_test_patch')

# %%
fig, ((ax1,ax2,ax3),(ax4,ax5,ax6))=plt.subplots(2,3)
ax1.plot(x,np.cos(x), color='#D426C8', alpha=0.8, linewidth=0.5)
ax2.plot(np.sin(x), color='blue',linestyle='--', alpha=0.5)
ax3.plot(x, x+0.5, color='#7CFC00', alpha=0.8, linewidth=0.6, linestyle='--')

ax4.plot(y,np.cos(y), color='#7CFC00', marker='s', linewidth=0.4)
ax5.plot(np.sin(y), color='red')
ax6.plot(np.tan(x), color='#D426C8')
fig.tight_layout()
