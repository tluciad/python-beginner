# %% [markdown]
# <a href="https://colab.research.google.com/github/tluciad/python-beginner/blob/main/Muestreo%20en%20python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Funciones de Muestreo en Python

# %%
import pandas as pd
import numpy as np
import random
import io

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c2dbbcad-0de2-442c-922d-ba72cececbbc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c2dbbcad-0de2-442c-922d-ba72cececbbc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
econdata = pd.read_csv(io.BytesIO(uploaded["econdata_ea911019-5acc-4c3e-94c1-4bae1896d167.csv"]))

# %%
econdata.head(3)
# Out:
#    id                  geo_point_2d  \
# 0   0   19.424781053,-99.1327537959
# 1   1  19.4346139576,-99.1413808393
# 2   2  19.4340695945,-99.1306348409
#
#                                            geo_shape   clave_cat  delegacion  \
# 0  {"type": "Polygon", "coordinates": [[[-99.1332...  307_130_11  Cuauhtémoc
# 1  {"type": "MultiPoint", "coordinates": [[-99.14...  002_008_01   Cuautémoc
# 2  {"type": "MultiPoint", "coordinates": [[-99.13...  006_002_12   Cuautémoc
#
#   perimetro     tipo                                             nom_id
# 0         B  Mercado                                        Pino Suárez
# 1         A    Museo  Museo Nacional de Arquitectura Palacio de Bell...
# 2         A    Museo                                       Santa Teresa

# %% [markdown]
# * Muestreo Aleatorio Simple

# %%
Aleatorio_8 = econdata.sample(n=8)
Aleatorio_8
# Out:
#       id                  geo_point_2d  \
# 178  178  19.4457531395,-99.1485982115
# 70    70       19.43712772,-99.1378899
# 136  136  19.4263840955,-99.1429192037
# 119  119      19.42240955,-99.15052984
# 219  219  19.4234096295,-99.1438351156
# 165  165  19.4248396624,-99.1333096809
# 131  131  19.4389531509,-99.1479144659
# 228  228  19.4406567734,-99.1394531646
#
#                                              geo_shape   clave_cat delegacion  \
# 178  {"type": "MultiPoint", "coordinates": [[-99.14...  012_069_11  Cuautémoc
# 70   {"type": "MultiPoint", "coordinates": [[-99.13...  004_090_02  Cuautémoc
# 136  {"type": "MultiPoint", "coordinates": [[-99.14...  002_084_14  Cuautémoc
# 119  {"type": "MultiPoint", "coordinates": [[-99.15...  002_097_02  Cuautémoc
# 219  {"type": "MultiPoint", "coordinates": [[-99.14...  002_118_03  Cuautémoc
# 165  {"type": "MultiPoint", "coordinates": [[-99.13...  001_086_01  Cuautémoc
# ...

# %%
Proporción_25 = econdata.sample(frac=0.25)
Proporción_25.head()
# Out:
#       id                  geo_point_2d  \
# 123  123  19.4378770032,-99.1358867181
# 54    54  19.4263645964,-99.1399088724
# 181  181  19.4451852396,-99.1478597989
# 119  119      19.42240955,-99.15052984
# 8      8   19.4343402009,-99.148212127
#
#                                              geo_shape   clave_cat delegacion  \
# 123  {"type": "MultiPoint", "coordinates": [[-99.13...  004_086_36  Cuautémoc
# 54   {"type": "MultiPoint", "coordinates": [[-99.13...  001_076_12  Cuautémoc
# 181  {"type": "MultiPoint", "coordinates": [[-99.14...  012_103_01  Cuautémoc
# 119  {"type": "MultiPoint", "coordinates": [[-99.15...  002_097_02  Cuautémoc
# 8    {"type": "MultiPoint", "coordinates": [[-99.14...  002_014_17  Cuautémoc
#
#     perimetro   tipo                  nom_id
# 123         A  Hotel                 Florida
# 54          B  Hotel  Cadillac, S.A. DE C.V.
# 181         B  Hotel                    Yale
# 119         B  Hotel                 Alcazar
# ...

# %% [markdown]
# * Muestreo Sistemático

# %%
def systematic_sampling(econdata,step):
  indexes = np.arange(0, len(econdata), step=step)
  systematic_sample = econdata.iloc[indexes]
  return systematic_sample

systematic_sample = systematic_sampling(econdata, 5)
systematic_sample.head(5)
# Out:
#     id                  geo_point_2d  \
# 0    0   19.424781053,-99.1327537959
# 5    5  19.4263287068,-99.1207277209
# 10  10    19.4441424478,-99.14600807
# 15  15       19.42413788,-99.1324515
# 20  20  19.4357307042,-99.1326583218
#
#                                             geo_shape   clave_cat  \
# 0   {"type": "Polygon", "coordinates": [[[-99.1332...  307_130_11
# 5   {"type": "MultiPoint", "coordinates": [[-99.12...  323_161_11
# 10  {"type": "MultiPoint", "coordinates": [[-99.14...  003_048_10
# 15  {"type": "MultiPoint", "coordinates": [[-99.13...  307_153_11
# 20  {"type": "MultiPoint", "coordinates": [[-99.13...  004_098_26
#
#              delegacion perimetro     tipo          nom_id
# 0            Cuauhtémoc         B  Mercado     Pino Suárez
# 5   Venustiano Carranza         B    Hotel  Baño San Tiago
# 10            Cuautémoc         B    Hotel       Moctezuma
# 15            Cuautémoc         B    Hotel       San Lucas
# ...

# %% [markdown]
# * Muestreo Estratificado en python

# %%
econdata['estratificado'] = econdata['delegacion'] + "," + econdata['tipo']
(econdata['estratificado'].value_counts()/len(econdata)).sort_values(ascending=False)
# Out:
# Cuautémoc,Hotel                0.643478
# Cuautémoc,Museo                0.156522
# Venustiano Carranza,Hotel      0.078261
# Cuauhtémoc,Mercado             0.073913
# Venustiano Carranza,Mercado    0.047826
# Name: estratificado, dtype: float64
