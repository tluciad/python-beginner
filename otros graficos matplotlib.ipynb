# %% [markdown]
# <a href="https://colab.research.google.com/github/tluciad/python-beginner/blob/main/otros%20graficos%20matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Histograma

# %%
import matplotlib.pyplot as plt
import numpy as np
data = np.random.randint(1,50,100)
data
# Out:
# array([33, 22, 20, 47,  8, 19,  7, 17, 38,  8, 41, 20, 34,  1,  3, 21, 42,
#        46, 31, 28, 23, 29, 28, 19, 25, 10, 42, 40, 36, 18, 28, 10,  9,  6,
#        45, 43,  7, 13, 21, 30, 28, 36,  5, 31,  5, 49, 24, 16,  3, 15, 37,
#        16, 47, 41, 20, 40,  2, 30, 29, 32,  2, 20, 31, 44, 23, 34, 46, 12,
#         3, 36, 32, 26, 15, 19, 43,  8, 20, 45,  6,  9, 19, 13, 47,  2, 31,
#        41, 28,  8, 38,  4, 46, 28, 41, 36, 36,  8, 27, 49, 17,  3])

# %%
plt.hist(data)
plt.show()

# %%
plt.hist(data, bins=30)
plt.show()

# %%
plt.hist(data, bins=10, histtype='step')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Grafico tipo Boxplot

# %%
plt.boxplot(data)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.boxplot(data, vert='false', patch_artist=True,notch=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Scatter con Area

# %%
N=50
x=np.random.rand(N)
y=np.random.rand(N)
area=(30*np.random.rand(N))*2
colors=np.random.rand(N)
plt.scatter(x,y,s=area)
plt.show()

# %%
plt.scatter(x, y, s=area, c=colors, marker='v')
plt.show()

# %%
plt.scatter(x, y, s=area, c=colors, marker='o',alpha=0.5)
plt.show()
